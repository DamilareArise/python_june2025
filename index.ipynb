# %%
import datetime as dt

dt.datetime?
# Out:
# Init signature: dt.datetime(self, /, *args, **kwargs)
# Docstring:
# datetime(year, month, day[, hour[, minute[, second[, microsecond[,tzinfo]]]]])
#
# The year, month and day arguments are required. tzinfo may be None, or an
# instance of a tzinfo subclass. The remaining arguments may be ints.
# File:           c:\users\welcome\anaconda3\lib\datetime.py
# Type:           type
# Subclasses:

# %%
from IPython.display import Image, Audio, Video

# %%
Image(r"C:\Users\Welcome\Downloads\benjamin-child-0sT9YhNgSEs-unsplash.jpg")
